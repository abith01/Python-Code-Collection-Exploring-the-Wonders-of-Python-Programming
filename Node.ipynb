# %% [markdown]
# AIM :
#    Create a Single Linked List with these data 10,20,30,40,50,60,70,80,90 using python programming
#
#
# a. Insert a new node with the data value 35 at the 3rd location.
# b. Insert a new node with the data value 75 at the 7th location
# c. Insert a new node with the data value 5 at the beginning of the linked list
# d. Insert a new node with the data value 100 at the end of the linked list
# e. Delete the node which has data value 60
# f. Delete the node which is in the 5th location
# g. Delete the beginning of the node
# h. Display the final nodes which are existing in the single linked list
#
# ALGORITHM :
#
# STEP 1: Creating the class
# STEP 2: Using a function to initialize
# STEP 3: Creating a self method
# STEP 4: Creating the class
# STEP 5: Initializing the method
# STEP 6: Adding the element in the third place
# STEP 7: Inserting the node at the seventh position
# STEP 8: Adding the node at the fifth position
# STEP 9: Inserting the node at the beginning
# STEP 10: Inserting the value in the middle
# STEP 11: Deleting the node which has data value 60
# STEP 12: Displaying the output

# %%
class node():
    def __init__(self,data):
        self.data=data
        self.link=None
class linked_list():
    def __init__(self):
        self.head=None
    def add(self,loc,data):
        newnode=node(data)
        var=self.head
        for i in range (loc-1):
            var=var.link
        newnode.link=var.link
        var.link=newnode
    def add2(self,loc,data):
        newnode=node(data)
        var=self.head
        for i in range(loc-1):
            var=var.link
        newnode.link=var.link
        var.link=newnode
    def add3(self,data):
        newnode=node(data)
        newnode.link=self.head
        self.head=newnode
    def add4(self,data):
        newnode=node(data)
        var=self.head
        while var.link is not None:
            var=var.link
        var.link=newnode
    def insert_loc5(self,data):
        newNode=self.head
        new2Node=self.head.link
        while(new2Node.data!=60):
            new2Node=new2Node.link
            newNode=newNode.link
        newNode.link=new2Node.link
        new2Node.link=None

    def delete_loc(self,loc):
        newNode=self.head
        new2Node=self.head.link
    def display(self):
        if self.head==None:
            print("its empty")
        else:
            var=self.head
            while var!=None:
                print(var.data,"-->",end=" ")
                var=var.link

n1=node(10)
s1=linked_list()
s1.head=n1
n2=node(20)
n1.link=n2
n3=node(30)
n2.link=n3
n4=node(40)
n3.link=n4
n5=node(50)
n4.link=n5
n6=node(60)
n5.link=n6
n7=node(70)
n6.link=n7
n8=node(80)
n7.link=n8
n9=node(90)
n8.link=n9
s1.add(3,35)
s1.add2(7,75)
s1.add3(5)
s1.add4(100)
s1.insert_loc5(60)
s1.delete_loc(5)

print(s1.display())
# Out:
# 5 --> 10 --> 20 --> 30 --> 35 --> 40 --> 50 --> 75 --> 70 --> 80 --> 90 --> 100 --> None
